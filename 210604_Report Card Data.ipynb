# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Combining Report Card Data

# %% [markdown]
# ## Teacher Retention

# %%
tr_df = pd.read_excel("teacher_retention.xlsx", sheet_name=0)

# %%
tr_df.head()
# Out:
#    district_number              district_name  school_number  school_name  \
# 0              300      Greene County Schools              0  All Schools
# 1              620      Monroe County Schools              0  All Schools
# 2              750  Rutherford County Schools              0  All Schools
# 3              860      Unicoi County Schools              0  All Schools
# 4               61     Cleveland City Schools              0  All Schools
#
#    year percent_retained
# 0  2019             90.5
# 1  2019             92.6
# 2  2019             88.9
# 3  2019             91.7
# 4  2019             90.3

# %%
tr_df = tr_df[tr_df.school_name != 'All Schools']

# %%
si_df = pd.read_excel("School_Info.xlsx", sheet_name=0)

# %%
si_df.shape
# Out:
# (1758, 14)

# %%
si_df.head(1)
# Out:
#    district_number            district_name  school_number  \
# 0               10  Anderson County Schools              2
#
#                    school_name  year     street_address     city state  \
# 0  Anderson County High School  2019  130 Maverick  Cir  Clinton    TN
#
#    zipcode          phone1  countyname_full countyname_short  principal  \
# 0    37716  (865) 457-4716  Anderson County         Anderson  Ben Downs
#
#   grades_served
# 0   Grades 9-12

# %% [markdown]
# ### Merging all of School_Info with only one Column ('percent_retention') from Teacher_Retention

# %%
combined_df = pd.merge(si_df, tr_df[['school_number','district_number','percent_retained']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 15)

# %%
combined_df.head()
# Out:
#    district_number            district_name  school_number  \
# 0               10  Anderson County Schools              2
# 1               10  Anderson County Schools              5
# 2               10  Anderson County Schools             10
# 3               10  Anderson County Schools             15
# 4               10  Anderson County Schools             20
#
#                    school_name  year      street_address           city state  \
# 0  Anderson County High School  2019   130 Maverick  Cir        Clinton    TN
# 1     Andersonville Elementary  2019  1951  Mountain  Rd  Andersonville    TN
# 2        Briceville Elementary  2019   103 Slatestone Rd     Briceville    TN
# 3           Claxton Elementary  2019  2218  Clinton  Hwy         Powell    TN
# 4        Clinton Middle School  2019    110  N  Hicks St        Clinton    TN
#
#    zipcode          phone1  countyname_full countyname_short  \
# 0    37716  (865) 457-4716  Anderson County         Anderson
# ...

# %%
#combined_df.to_excel(r'schools_retention_test.xlsx', index = False)

# %%
#renamed percent_retained to teacher_retention
combined_df.rename({'percent_retained' : 'teacher_retention'}, axis=1);

# %% [markdown]
# ## Achievement

# %%
#ach_df = pd.read_excel("achievement.xlsx", sheet_name=0)

# %%
#ach_df.head()

# %%
#filtered_df = df[(df["A"] < 1) & (df["B"] == 1)]

# %%
#ach_df = ach_df[(ach_df['school_name'] != 'All Schools') & (ach_df['subgroup'] == 'all_students')]

# %%
#ach_df = ach_df[(ach_df.school_name != 'All Schools') & (ach_df.subgroup == 'all_students')]

# %%
#ach_df.shape

# %%
#ach_df = ach_df[(ach_df.school_name != 'All Schools') & (ach_df.subgroup == 'all_students') & (ach_df.overall_subject != 'Social Studies') ]

# %%
#ach_df.shape

# %% [markdown]
# ## ACT

# %%
act_df = pd.read_excel("ACT.xlsx", sheet_name=0)

# %%
act_df = act_df[(act_df.school_name != 'All Schools') & (act_df.subgroup == 'all_students')]

# %%
act_df.head()
# Out:
#     district_number            district_name  school_number  \
# 18               10  Anderson County Schools              2
# 24               10  Anderson County Schools              5
# 30               10  Anderson County Schools             10
# 36               10  Anderson County Schools             15
# 42               10  Anderson County Schools             20
#
#                     school_name  year      subgroup english_avg math_avg  \
# 18  Anderson County High School  2018  all_students        19.1     19.2
# 24     Andersonville Elementary  2018  all_students         NaN      NaN
# 30        Briceville Elementary  2018  all_students         NaN      NaN
# 36           Claxton Elementary  2018  all_students         NaN      NaN
# 42        Clinton Middle School  2018  all_students         NaN      NaN
#
#    reading_avg science_avg  ... percent_21_orhigher percent_met_crb_english  \
# 18          20        20.1  ...                41.6                    58.6
# ...

# %%
act_df.shape
# Out:
# (1758, 21)

# %%
combined_df.shape
# Out:
# (1758, 15)

# %%
combined_df = pd.merge(combined_df, act_df[['school_number','district_number','act_composite_avg', 'percent_21_orhigher', 'avg_composite_previous']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 18)

# %%
combined_df.tail()
# Out:
#       district_number                       district_name  school_number  \
# 1753              985         Achievement School District           8130
# 1754              985         Achievement School District           8135
# 1755              985         Achievement School District           8140
# 1756              986  Tennessee State Board of Education           8005
# 1757              986  Tennessee State Board of Education           8015
#
#                                school_name  year            street_address  \
# 1753        Memphis Scholars Raleigh-Egypt  2019  1380 Pennsylvania Avenue
# 1754                   Kirby Middle School  2019          6670 E Raines Rd
# 1755                 Hillcrest High School  2019         4184 Graceland Dr
# 1756                Bluff City High School  2019              4100 Ross Rd
# 1757  KIPP Antioch College Prep Elementary  2019    3655 Murfreesboro Pike
#
#          city state  zipcode          phone1  countyname_full  \
# ...

# %%
combined_df = pd.merge(combined_df, act_df[['school_number','district_number', 'percent_21_orhigher_previous']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 19)

# %%
combined_df.tail()
# Out:
#       district_number                       district_name  school_number  \
# 1753              985         Achievement School District           8130
# 1754              985         Achievement School District           8135
# 1755              985         Achievement School District           8140
# 1756              986  Tennessee State Board of Education           8005
# 1757              986  Tennessee State Board of Education           8015
#
#                                school_name  year            street_address  \
# 1753        Memphis Scholars Raleigh-Egypt  2019  1380 Pennsylvania Avenue
# 1754                   Kirby Middle School  2019          6670 E Raines Rd
# 1755                 Hillcrest High School  2019         4184 Graceland Dr
# 1756                Bluff City High School  2019              4100 Ross Rd
# 1757  KIPP Antioch College Prep Elementary  2019    3655 Murfreesboro Pike
#
#          city state  zipcode          phone1  countyname_full  \
# ...

# %%
combined_df.shape
# Out:
# (1758, 19)

# %%
combined_df = combined_df.rename({'act_composite_avg' : 'act_composite_avg_2018', 'avg_composite_previous':'act_composite_avg_2017', 'percent_21_orhigher': 'act_%above_21_2018', 'percent_21_orhigher_previous': 'act_%above_21_2017'}, axis=1)

# %%
combined_df.head()
# Out:
#    district_number            district_name  school_number  \
# 0               10  Anderson County Schools              2
# 1               10  Anderson County Schools              5
# 2               10  Anderson County Schools             10
# 3               10  Anderson County Schools             15
# 4               10  Anderson County Schools             20
#
#                    school_name  year      street_address           city state  \
# 0  Anderson County High School  2019   130 Maverick  Cir        Clinton    TN
# 1     Andersonville Elementary  2019  1951  Mountain  Rd  Andersonville    TN
# 2        Briceville Elementary  2019   103 Slatestone Rd     Briceville    TN
# 3           Claxton Elementary  2019  2218  Clinton  Hwy         Powell    TN
# 4        Clinton Middle School  2019    110  N  Hicks St        Clinton    TN
#
#    zipcode          phone1  countyname_full countyname_short  \
# 0    37716  (865) 457-4716  Anderson County         Anderson
# ...

# %%
combined_df.shape
# Out:
# (1758, 19)

# %% [markdown]
# ## Grad Rate

# %%
grad_df = pd.read_excel("grad_rate.xlsx", sheet_name=0)

# %%
grad_df.head()
# Out:
#    district_number       district_name  school_number  school_name  year  \
# 0                0  State of Tennessee              0  All Schools  2018
# 1                0  State of Tennessee              0  All Schools  2018
# 2                0  State of Tennessee              0  All Schools  2018
# 3                0  State of Tennessee              0  All Schools  2018
# 4                0  State of Tennessee              0  All Schools  2018
#
#        subgroup  denominator grad_rate grad_rate_previous  baseline_year
# 0  all_students      72784.0      89.1               89.1           2017
# 1  all_students      72784.0      89.1               89.1           2017
# 2           bhn      24112.0      82.6               83.0           2017
# 3           bhn      24112.0      82.6               83.0           2017
# 4            ed      26714.0      82.1               83.7           2017

# %%
grad_df = grad_df[(grad_df.school_name != 'All Schools') & (grad_df.subgroup == 'all_students')]

# %%
grad_df.head()
# Out:
#      district_number            district_name  school_number  \
# 48                10  Anderson County Schools              2
# 64                10  Anderson County Schools              5
# 80                10  Anderson County Schools             10
# 96                10  Anderson County Schools             15
# 112               10  Anderson County Schools             20
#
#                      school_name  year      subgroup  denominator grad_rate  \
# 48   Anderson County High School  2018  all_students        243.0      98.4
# 64      Andersonville Elementary  2018  all_students          NaN         *
# 80         Briceville Elementary  2018  all_students          NaN         *
# 96            Claxton Elementary  2018  all_students          NaN         *
# 112        Clinton Middle School  2018  all_students          NaN         *
#
#     grad_rate_previous  baseline_year
# 48                95.4           2017
# 64                 NaN           2017
# ...

# %%
grad_df = grad_df.rename({'grad_rate' : 'grad_rate_2018', 'grad_rate_previous':'grad_rate_2017'}, axis=1)

# %%
combined_df.shape
# Out:
# (1758, 19)

# %%
combined_df = pd.merge(combined_df, grad_df[['school_number','district_number','grad_rate_2018', 'grad_rate_2017']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 21)

# %% [markdown]
# ## Overall Grades

# %%
overall_df = pd.read_excel("overall_grades.xlsx", sheet_name=0)

# %%
overall_df.head()
# Out:
#    district_number            district_name  school_number  \
# 0               10  Anderson County Schools              2
# 1               10  Anderson County Schools              5
# 2               10  Anderson County Schools             10
# 3               10  Anderson County Schools             15
# 4               10  Anderson County Schools             20
#
#                    school_name  year pool  score_achievement  score_growth  \
# 0  Anderson County High School  2019   HS                2.6           3.6
# 1     Andersonville Elementary  2019   K8                4.0           3.4
# 2        Briceville Elementary  2019   K8                2.0           3.8
# 3           Claxton Elementary  2019   K8                2.0           2.7
# 4        Clinton Middle School  2019   K8                1.7           0.5
#
#    score_absenteeism  score_elpa  score_grad  score_ready_grad
# 0                4.0         NaN         4.0               4.0
# ...

# %%
combined_df = pd.merge(combined_df, overall_df[['school_number','district_number','score_achievement', 'score_absenteeism']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 23)

# %% [markdown]
# ## Staffing

# %%
staffing_df = pd.read_excel("staffing.xlsx", sheet_name=0)

# %%
staffing_df.head()
# Out:
#    district_number       district_name  school_number  school_name  year  \
# 0                0  State of Tennessee              0  All Schools  2019
# 1                0  State of Tennessee              0  All Schools  2019
# 2                0  State of Tennessee              0  All Schools  2019
# 3                0  State of Tennessee              0  All Schools  2019
# 4                0  State of Tennessee              0  All Schools  2019
#
#    n_staff           role entity
# 0     3950          admin  state
# 1     3950          admin  state
# 2      974  support_coach  state
# 3      974  support_coach  state
# 4     2468   support_coun  state

# %%
staffing_df = staffing_df[(staffing_df.school_name != 'All Schools') & (staffing_df.role == 'teacher')]

# %%
staffing_df = staffing_df.rename({'entity' : 'staffing_entity'}, axis=1)

# %%
combined_df = pd.merge(combined_df, staffing_df[['school_number','district_number','n_staff', 'staffing_entity']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 25)

# %% [markdown]
# ## School Coordinates

# %%
coord_df = pd.read_excel("latlon_school_complete.xlsx", sheet_name=0)

# %%
coord_df.head()
# Out:
#    district_number            district_name  school_number  \
# 0               10  Anderson County Schools              2
# 1               10  Anderson County Schools              5
# 2               10  Anderson County Schools             10
# 3               10  Anderson County Schools             15
# 4               10  Anderson County Schools             20
#
#                    school_name  zipcode            school_name_coord  \
# 0  Anderson County High School    37716  Anderson County High School
# 1     Andersonville Elementary    37705     Andersonville Elementary
# 2        Briceville Elementary    37710        Briceville Elementary
# 3           Claxton Elementary    37849           Claxton Elementary
# 4        Clinton Middle School    37716        Clinton Middle School
#
#                STREET           CITY  zipcode_coord      county_name  \
# 0    130 Maverick CIR        Clinton        37716.0  Anderson County
# ...

# %%
combined_df = pd.merge(combined_df, coord_df[['school_number','district_number', 'lat', 'lon']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 27)

# %% [markdown]
# ## Create uid

# %%
combined_df['uid'] = combined_df['district_number'].astype(str) + combined_df['school_number'].astype(str)

# %%
combined_df.shape
# Out:
# (1758, 28)

# %%
combined_df.head()
# Out:
#    district_number            district_name  school_number  \
# 0               10  Anderson County Schools              2
# 1               10  Anderson County Schools              5
# 2               10  Anderson County Schools             10
# 3               10  Anderson County Schools             15
# 4               10  Anderson County Schools             20
#
#                    school_name  year      street_address           city state  \
# 0  Anderson County High School  2019   130 Maverick  Cir        Clinton    TN
# 1     Andersonville Elementary  2019  1951  Mountain  Rd  Andersonville    TN
# 2        Briceville Elementary  2019   103 Slatestone Rd     Briceville    TN
# 3           Claxton Elementary  2019  2218  Clinton  Hwy         Powell    TN
# 4        Clinton Middle School  2019    110  N  Hicks St        Clinton    TN
#
#    zipcode          phone1  ... act_%above_21_2017 grad_rate_2018  \
# 0    37716  (865) 457-4716  ...               39.7           98.4
# ...

# %%
#combined_df.to_excel(r'combined_RCD_test.xlsx', index = False)

# %%
combined_df.shape
# Out:
# (1758, 28)

# %%
combined_df.shape
# Out:
# (1758, 28)

# %% [markdown]
# ## Achievement 2019

# %%
ach_df = pd.read_excel("achievement.xlsx", sheet_name=0)

# %%
ach_df = ach_df[(ach_df.school_name != 'All Schools') & (ach_df.subgroup == 'all_students') & (ach_df.overall_subject != 'Social Studies') ]

# %%
ach_df.drop(columns=['percent_mastered'], inplace=True)

# %%
pivoted_data = pd.pivot_table(ach_df, index=['district_name', 'district_number','school_name', 'school_number', 'year', 'subgroup'], columns='overall_subject', values='percent_on_mastered', aggfunc='first').reset_index()

# %%
pivoted_data = pivoted_data.rename({'ELA' : 'ela_2019', 'Math' : 'math_2019'}, axis=1)

# %%
combined_df = pd.merge(combined_df, pivoted_data[['school_number','district_number','ela_2019', 'math_2019']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 30)

# %%
pivoted_data2 = pd.pivot_table(ach_df, index=['district_name', 'district_number','school_name', 'school_number', 'year', 'subgroup'], columns='overall_subject', values='percent_on_mastered_previous', aggfunc='first').reset_index()

# %%
pivoted_data2 = pivoted_data2.rename({'ELA' : 'ela_2018', 'Math' : 'math_2018'}, axis=1)

# %%
combined_df = pd.merge(combined_df, pivoted_data2[['school_number','district_number','ela_2018', 'math_2018']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 32)

# %% [markdown]
# ## Achievement 2017

# %%
ach2018_df = pd.read_excel("achievement_2018.xlsx", sheet_name=0)

# %%
ach2018_df = ach2018_df[(ach2018_df.school_number != 0) & (ach2018_df.subgroup == 'All Students') & (ach2018_df.overall_subject != 'Social Studies') & (ach2018_df.overall_subject != 'Science')]

# %%
Ach_2018_pivoted_data = pd.pivot_table(ach2018_df, index=['district_name', 'district_number','school_name', 'school_number', 'year', 'subgroup'], columns='overall_subject', values='percent_on_mastered_previous', aggfunc='first').reset_index()

# %%
Ach_2018_pivoted_data = Ach_2018_pivoted_data.rename({'ELA' : 'ela_2017', 'Math' : 'math_2017'}, axis=1)

# %%
combined_df = pd.merge(combined_df, Ach_2018_pivoted_data[['school_number','district_number','ela_2017', 'math_2017']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 34)

# %% [markdown]
# ## Finance

# %%
fin_df = pd.read_excel("finance.xlsx", sheet_name=0)

# %%
fin_df = fin_df[(fin_df['School Name'] != 'District Average/Total')]

# %%
fin_df = fin_df.rename({'Total School Per Pupil Expenditures' : 'funding_per_student'}, axis=1)

# %%
fin_df = fin_df.rename({'School ID' : 'school_number', 'District ID':'district_number'}, axis=1)

# %%
combined_df = pd.merge(combined_df, fin_df[['school_number', 'district_number', 'funding_per_student']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 35)

# %% [markdown]
# ## Teacher Experience

# %%
te_df = pd.read_excel("teacher_experience_school.xlsx", sheet_name=0)

# %%
te_df = te_df[(te_df.category == 'Inexperienced Teachers')]

# %%
combined_df = pd.merge(combined_df, te_df[['school_number', 'district_number', 'inexperience_pct']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 36)

# %% [markdown]
# ## Drop, Re-add Staff

# %%
combined_df.drop(columns=['n_staff', 'staffing_entity'], inplace=True)

# %%
staffing_df = pd.read_excel("staffing.xlsx", sheet_name=0)

# %%
staffing_df = staffing_df[(staffing_df.school_name != 'All Schools')]

# %%
pivoted_data_staff = pd.pivot_table(staffing_df, index=['district_name', 'district_number','school_name', 'school_number', 'year'], columns='role', values='n_staff', aggfunc='first').reset_index()

# %%
pivoted_data_staff = pivoted_data_staff.rename({'teacher' : 'staff_teacher'}, axis=1)

# %%
pivoted_data_staff = pivoted_data_staff.rename({'all_educators' : 'staff_all_educators'}, axis=1)

# %%
combined_df = pd.merge(combined_df, pivoted_data_staff[['school_number', 'district_number', 'admin', 'staff_all_educators', 'support_coach', 'support_coun', 'support_inter', 'support_librarian', 'support_other', 'staff_teacher']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 42)

# %% [markdown]
# ## Discipline

# %%
d_df = pd.read_excel("discipline.xlsx", sheet_name=0)

# %%
d_df = d_df[(d_df.school_name != 'All Schools') & (d_df.subgroup == 'all_students') & (d_df.disciplinary_type != 'R')]

# %%
pivoted_data_d = pd.pivot_table(d_df, index=['district_name', 'district_number','school_name', 'school_number', 'year'], columns='disciplinary_type', values='percent', aggfunc='first').reset_index()

# %%
pivoted_data_d.head()
# Out:
# disciplinary_type                district_name  district_number  \
# 0                  Achievement School District              985
# 1                  Achievement School District              985
# 2                  Achievement School District              985
# 3                  Achievement School District              985
# 4                  Achievement School District              985
#
# disciplinary_type                         school_name  school_number  year  \
# 0                                      Aspire Coleman           8050  2019
# 1                            Aspire Hanley Elementary           8025  2019
# 2                         Aspire Hanley Middle School           8024  2019
# 3                  Brick Church: A LEAD Public School           8005  2019
# 4                    Cornerstone Prep - Lester Campus           8010  2019
#
# disciplinary_type    E    I     S
# 0                  0.3  0.1   8.1
# 1                  0.2  1.2  15.2
# ...

# %%
pivoted_data_d = pivoted_data_d.rename({'E' : 'expulsion_pct2019', 'I' : 'in_school_suspension_pct2019' , 'S' : 'suspension_pct2019'},axis=1)

# %%
pivoted_data_d.head()
# Out:
# disciplinary_type                district_name  district_number  \
# 0                  Achievement School District              985
# 1                  Achievement School District              985
# 2                  Achievement School District              985
# 3                  Achievement School District              985
# 4                  Achievement School District              985
#
# disciplinary_type                         school_name  school_number  year  \
# 0                                      Aspire Coleman           8050  2019
# 1                            Aspire Hanley Elementary           8025  2019
# 2                         Aspire Hanley Middle School           8024  2019
# 3                  Brick Church: A LEAD Public School           8005  2019
# 4                    Cornerstone Prep - Lester Campus           8010  2019
#
# disciplinary_type expulsion_pct2019 in_school_suspension_pct2019  \
# ...

# %%
combined_df = pd.merge(combined_df, pivoted_data_d[['school_number', 'district_number', 'expulsion_pct2019', 'in_school_suspension_pct2019', 'suspension_pct2019']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 45)

# %%
pivoted_data_d2 = pd.pivot_table(d_df, index=['district_name', 'district_number','school_name', 'school_number', 'year'], columns='disciplinary_type', values='percent_previous', aggfunc='first').reset_index()

# %%
pivoted_data_d2.head()
# Out:
# disciplinary_type                district_name  district_number  \
# 0                  Achievement School District              985
# 1                  Achievement School District              985
# 2                  Achievement School District              985
# 3                  Achievement School District              985
# 4                  Achievement School District              985
#
# disciplinary_type                         school_name  school_number  year  E  \
# 0                                      Aspire Coleman           8050  2019  0
# 1                            Aspire Hanley Elementary           8025  2019  0
# 2                         Aspire Hanley Middle School           8024  2019  0
# 3                  Brick Church: A LEAD Public School           8005  2019  0
# 4                    Cornerstone Prep - Lester Campus           8010  2019  0
#
# disciplinary_type  I     S
# 0                  0   7.1
# 1                  0  11.8
# ...

# %%
pivoted_data_d2 = pivoted_data_d2.rename({'E' : 'expulsion_pct2018', 'I' : 'in_school_suspension_pct2018' , 'S' : 'suspension_pct2018'},axis=1)

# %%
pivoted_data_d2.head()
# Out:
# disciplinary_type                district_name  district_number  \
# 0                  Achievement School District              985
# 1                  Achievement School District              985
# 2                  Achievement School District              985
# 3                  Achievement School District              985
# 4                  Achievement School District              985
#
# disciplinary_type                         school_name  school_number  year  \
# 0                                      Aspire Coleman           8050  2019
# 1                            Aspire Hanley Elementary           8025  2019
# 2                         Aspire Hanley Middle School           8024  2019
# 3                  Brick Church: A LEAD Public School           8005  2019
# 4                    Cornerstone Prep - Lester Campus           8010  2019
#
# disciplinary_type expulsion_pct2018 in_school_suspension_pct2018  \
# ...

# %%
combined_df = pd.merge(combined_df, pivoted_data_d2[['school_number', 'district_number', 'expulsion_pct2018', 'in_school_suspension_pct2018', 'suspension_pct2018']], on=['school_number', 'district_number'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 48)

# %% [markdown]
# ## School Ethnic Breakdown % 2019

# %%
#school_eth = pd.read_excel("school_ethnic_breakdown_pct_2019.xlsx", sheet_name=0)

# %%
#school_eth.head()

# %%
#combined_df = pd.merge(combined_df, school_eth[['school_name', 'aa_pct2019', 'white_pct2019', 'hispanic_pct2019', 'asian_pct2019', 'other_ethnicity_pct2019']], on=['school_name'], how='left')

# %%
#combined_df.shape

# %%
#combined_df.info()

# %% [markdown]
# ## Zipcode Student Populations by Ethnicity

# %%
zip_eth = pd.read_excel("ethnicity_with_total_students_complete_pct.xlsx", sheet_name=0)

# %%
zip_eth.head()
# Out:
#    eth_zip  eth_white_pct  eth_aa_pct  eth_hispanic_pct  eth_asian_pct  \
# 0    37010      90.753691    1.631702          4.506605       2.097902
# 1    37012      77.531646    6.329114         16.139241       0.000000
# 2    37013      31.644383   33.435295         26.103903       4.716562
# 3    37014      94.767442    0.000000          1.356589       3.875969
# 4    37015      85.891720    0.859873         10.923567       0.859873
#
#    eth_other_pct
# 0       1.010101
# 1       0.000000
# 2       4.099857
# 3       0.000000
# 4       1.464968

# %%
zip_eth = zip_eth.rename({'eth_zip' : 'zipcode'},axis=1)

# %%
combined_df = pd.merge(combined_df, zip_eth[['zipcode', 'eth_white_pct', 'eth_aa_pct', 'eth_hispanic_pct', 'eth_asian_pct', 'eth_other_pct']], on=['zipcode'], how='left')

# %%
combined_df.shape
# Out:
# (1758, 53)

# %%
#combined_df.to_excel(r'210604_Data_Fail_Safe.xlsx', index = False)

# %% [markdown]
# ## School Rank

# %%
rank = pd.read_excel("210604_school_rank_complete.xlsx", sheet_name=0)

# %%
rank.head()
# Out:
#    district_number                                district_name  \
# 0              190               Metro Nashville Public Schools
# 1              630  Clarksville-Montgomery County School System
# 2              830                        Sumner County Schools
# 3              330                      Hamilton County Schools
# 4              750                    Rutherford County Schools
#
#    school_number                                        school_name  year  \
# 0            456                       Martin Luther King Jr School  2019
# 1             88      Middle College @ Austin Peay State University  2019
# 2             53                          Merrol Hyde Magnet School  2019
# 3             86  Hamilton County Collegiate High at Chattanooga...  2019
# 4             70                      McFadden School Of Excellence  2019
#
#          street_address_1 street_address_2  street_address_3            city  \
# ...

# %%
pivoted_data_r = pd.pivot_table(rank, index=['district_name', 'district_number','school_name', 'school_number', 'year'], columns='school_type_EMH', values='school_rank_2019', aggfunc='first').reset_index()

# %%
pivoted_data_r.head()
# Out:
# school_type_EMH                district_name  district_number  \
# 0                Achievement School District              985
# 1                Achievement School District              985
# 2                Achievement School District              985
# 3                Achievement School District              985
# 4                Achievement School District              985
#
# school_type_EMH                         school_name  school_number  year  \
# 0                                    Aspire Coleman           8050  2019
# 1                          Aspire Hanley Elementary           8025  2019
# 2                       Aspire Hanley Middle School           8024  2019
# 3                Brick Church: A LEAD Public School           8005  2019
# 4                  Cornerstone Prep - Lester Campus           8010  2019
#
# school_type_EMH  Elementary  High  Middle
# 0                     964.0   NaN   552.0
# 1                     958.0   NaN   537.0
# ...

# %%
pivoted_data_r = pivoted_data_r.rename({'Elementary' : 'rank_elementary_2019', 'Middle':'rank_middle_2019', 'High':'rank_high_2019'}, axis=1)

# %%
pivoted_data_r.head()
# Out:
# school_type_EMH                district_name  district_number  \
# 0                Achievement School District              985
# 1                Achievement School District              985
# 2                Achievement School District              985
# 3                Achievement School District              985
# 4                Achievement School District              985
#
# school_type_EMH                         school_name  school_number  year  \
# 0                                    Aspire Coleman           8050  2019
# 1                          Aspire Hanley Elementary           8025  2019
# 2                       Aspire Hanley Middle School           8024  2019
# 3                Brick Church: A LEAD Public School           8005  2019
# 4                  Cornerstone Prep - Lester Campus           8010  2019
#
# school_type_EMH  rank_elementary_2019  rank_high_2019  rank_middle_2019
# 0                               964.0             NaN             552.0
# ...

# %% [markdown]
# ### Creating a fail safe here by calling new combined df as combined_df2. Original was combined_df

# %%
combined_df2 = pd.merge(combined_df, pivoted_data_r[['school_number','district_number','rank_elementary_2019', 'rank_middle_2019', 'rank_high_2019']], on=['school_number', 'district_number'], how='left')

# %%
combined_df2.shape
# Out:
# (1758, 56)

# %%
pivoted_data_r2 = pd.pivot_table(rank, index=['district_name', 'district_number','school_name', 'school_number', 'year'], columns='school_type_EMH', values='rank_chg_from_2018', aggfunc='first').reset_index()

# %%
pivoted_data_r2.head()
# Out:
# school_type_EMH                district_name  district_number  \
# 0                Achievement School District              985
# 1                Achievement School District              985
# 2                Achievement School District              985
# 3                Achievement School District              985
# 4                Achievement School District              985
#
# school_type_EMH                         school_name  school_number  year  \
# 0                                    Aspire Coleman           8050  2019
# 1                          Aspire Hanley Elementary           8025  2019
# 2                       Aspire Hanley Middle School           8024  2019
# 3                Brick Church: A LEAD Public School           8005  2019
# 4                  Cornerstone Prep - Lester Campus           8010  2019
#
# school_type_EMH Elementary High Middle
# 0                      -10  NaN    -34
# 1                       14  NaN    -27
# ...

# %%
pivoted_data_r2 = pivoted_data_r2.rename({'Elementary' : 'elementary_rank_chg_2018', 'Middle':'middle_rank_chg_2018', 'High':'high_rank_chg_2018'}, axis=1)

# %%
pivoted_data_r2.head()
# Out:
# school_type_EMH                district_name  district_number  \
# 0                Achievement School District              985
# 1                Achievement School District              985
# 2                Achievement School District              985
# 3                Achievement School District              985
# 4                Achievement School District              985
#
# school_type_EMH                         school_name  school_number  year  \
# 0                                    Aspire Coleman           8050  2019
# 1                          Aspire Hanley Elementary           8025  2019
# 2                       Aspire Hanley Middle School           8024  2019
# 3                Brick Church: A LEAD Public School           8005  2019
# 4                  Cornerstone Prep - Lester Campus           8010  2019
#
# school_type_EMH elementary_rank_chg_2018 high_rank_chg_2018  \
# 0                                    -10                NaN
# ...

# %%
combined_df2 = pd.merge(combined_df2, pivoted_data_r2[['school_number','district_number','elementary_rank_chg_2018', 'middle_rank_chg_2018', 'high_rank_chg_2018']], on=['school_number', 'district_number'], how='left')

# %%
combined_df2.shape
# Out:
# (1758, 59)

# %% [markdown]
# ## Gini Index

# %%
gini_df = pd.read_excel('gini_index.xlsx', skiprows = 1, header=[0,1], sheet_name=0)
gini_df = gini_df[gini_df.columns.drop(list(gini_df.filter(regex='Error')))]
gini_df.columns = gini_df.columns.droplevel(1)

# %%
gini_df.head()
# Out:
#   Unnamed: 0_level_0   28622   28705   28754   28771   28906   35739   37010  \
# 0         Gini Index  0.4417  0.3861  0.4881  0.4402  0.4147  0.4406  0.3888
#
#     37012   37013  ...   38581   38582   38583   38585   38587   38588  38589  \
# 0  0.4158  0.3858  ...  0.4297  0.5156  0.4388  0.3995  0.4516  0.4907  0.388
#
#     42223   42602  72338
# 0  0.3213  0.5178    NaN
#
# [1 rows x 638 columns]

# %%
gini_df.drop(columns=['28754','28705','28622','42602', '28771','28906', '35739'], inplace=True)
gini_df.head()
# Out:
#   Unnamed: 0_level_0   37010   37012   37013   37014   37015   37016   37018  \
# 0         Gini Index  0.3888  0.4158  0.3858  0.4328  0.3718  0.4447  0.4574
#
#     37019  37020  ...   38580   38581   38582   38583   38585   38587   38588  \
# 0  0.3245  0.367  ...  0.4073  0.4297  0.5156  0.4388  0.3995  0.4516  0.4907
#
#    38589   42223  72338
# 0  0.388  0.3213    NaN
#
# [1 rows x 631 columns]

# %%
gini_df_clean = gini_df.set_index('Unnamed: 0_level_0').T.reset_index().rename({'index' : 'zipcode'}, axis=1)

# %%
gini_df_clean.head()
# Out:
# Unnamed: 0_level_0 zipcode  Gini Index
# 0                    37010      0.3888
# 1                    37012      0.4158
# 2                    37013      0.3858
# 3                    37014      0.4328
# 4                    37015      0.3718

# %%
#need to convert zipcode to type 'int' to perfom merge
gini_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   zipcode     630 non-null    object
#  1   Gini Index  615 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 10.0+ KB

# %%
gini_df_clean.zipcode = gini_df_clean.zipcode.astype('float64')

# %%
gini_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   zipcode     630 non-null    float64
#  1   Gini Index  615 non-null    float64
# dtypes: float64(2)
# memory usage: 10.0 KB

# %%
gini_df_clean.zipcode = gini_df_clean.zipcode.astype('str')

# %%
gini_df_clean.zipcode = gini_df_clean.zipcode.str.replace('.0', '', regex=False)

# %%
gini_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   zipcode     630 non-null    object
#  1   Gini Index  615 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 10.0+ KB

# %%
gini_df_clean.zipcode = gini_df_clean.zipcode.astype('int')

# %%
gini_df_clean.head()
# Out:
# Unnamed: 0_level_0  zipcode  Gini Index
# 0                     37010      0.3888
# 1                     37012      0.4158
# 2                     37013      0.3858
# 3                     37014      0.4328
# 4                     37015      0.3718

# %%
combined_df2 = pd.merge(combined_df2, gini_df_clean[['zipcode','Gini Index']], on=['zipcode'], how='left')

# %%
combined_df2.shape
# Out:
# (1758, 60)

# %%
combined_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1758 entries, 0 to 1757
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   district_number               1758 non-null   int64
#  1   district_name                 1758 non-null   object
#  2   school_number                 1758 non-null   int64
#  3   school_name                   1758 non-null   object
#  4   year                          1758 non-null   int64
#  5   street_address                1758 non-null   object
#  6   city                          1758 non-null   object
#  7   state                         1758 non-null   object
#  8   zipcode                       1758 non-null   int64
#  9   phone1                        1758 non-null   object
#  10  countyname_full               1758 non-null   object
#  11  countyname_short              1758 non-null   object
# ...

# %% [markdown]
# ## Enrollment

# %%
enr_df = pd.read_excel("enrollment.xlsx", sheet_name=0)

# %%
enr_df.head()
# Out:
#    district_number       district_name  school_number  school_name  year  \
# 0                0  State of Tennessee              0  All Schools  2019
# 1                0  State of Tennessee              0  All Schools  2019
# 2                0  State of Tennessee              0  All Schools  2019
# 3                0  State of Tennessee              0  All Schools  2019
# 4                0  State of Tennessee              0  All Schools  2019
#
#        subgroup grades_served     value  value_previous
# 0  all_students         PK-12  973659.0        975222.0
# 1  all_students         PK-12  973659.0        975222.0
# 2           bhn         PK-12      35.2            34.7
# 3           bhn         PK-12      35.2            34.7
# 4            ed         PK-12      34.9            36.1

# %%
enr_df = enr_df[(enr_df.district_name != 'State of Tennessee') & (enr_df.school_number != 0) & (enr_df.subgroup == 'all_students')]

# %%
enr_df.head()
# Out:
#       district_number            district_name  school_number  \
# 2682               10  Anderson County Schools              2
# 2700               10  Anderson County Schools              5
# 2718               10  Anderson County Schools             10
# 2736               10  Anderson County Schools             15
# 2754               10  Anderson County Schools             20
#
#                       school_name  year      subgroup grades_served   value  \
# 2682  Anderson County High School  2019  all_students   Grades 9-12  1075.0
# 2700     Andersonville Elementary  2019  all_students   Grades PK-5   304.0
# 2718        Briceville Elementary  2019  all_students   Grades PK-5   117.0
# 2736           Claxton Elementary  2019  all_students   Grades PK-5   443.0
# 2754        Clinton Middle School  2019  all_students    Grades 6-8   664.0
#
#       value_previous
# 2682          1056.0
# 2700           310.0
# 2718           109.0
# 2736           459.0
# 2754           666.0

# %%
enr_df = enr_df.rename({'value' : 'enrollment_2019', 'value_previous' : 'enrollment_2018'},axis=1)

# %%
combined_df2 = pd.merge(combined_df2, enr_df[['school_number','district_number', 'enrollment_2019', 'enrollment_2018']], on=['school_number', 'district_number'], how='left')

# %%
combined_df2.shape
# Out:
# (1758, 62)

# %%
#combined_df2.to_excel(r'210606_combined_school_test.xlsx', index = False)

# %% [markdown]
# ## Updated School Ethnic Breakdown % 2019

# %%
combined_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1758 entries, 0 to 1757
# Data columns (total 62 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   district_number               1758 non-null   int64
#  1   district_name                 1758 non-null   object
#  2   school_number                 1758 non-null   int64
#  3   school_name                   1758 non-null   object
#  4   year                          1758 non-null   int64
#  5   street_address                1758 non-null   object
#  6   city                          1758 non-null   object
#  7   state                         1758 non-null   object
#  8   zipcode                       1758 non-null   int64
#  9   phone1                        1758 non-null   object
#  10  countyname_full               1758 non-null   object
#  11  countyname_short              1758 non-null   object
# ...

# %%
school_ethnic2 = pd.read_excel("210608_school_ethnic_breakdown_pct_2019.xlsx", sheet_name=0)

# %%
school_ethnic2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1756 entries, 0 to 1755
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   school_name              1756 non-null   object
#  1   district_number          1756 non-null   int64
#  2   school_number            1756 non-null   int64
#  3   aa_pct2019               1756 non-null   float64
#  4   white_pct2019            1756 non-null   float64
#  5   hispanic_pct2019         1756 non-null   float64
#  6   asian_pct2019            1756 non-null   float64
#  7   other_ethnicity_pct2019  1756 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 109.9+ KB

# %%
combined_df3 = pd.merge(combined_df2, school_ethnic2[['school_number','district_number', 'aa_pct2019', 'white_pct2019', 'hispanic_pct2019', 'asian_pct2019', 'other_ethnicity_pct2019']], on=['school_number', 'district_number'], how='left')

# %%
combined_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1758 entries, 0 to 1757
# Data columns (total 67 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   district_number               1758 non-null   int64
#  1   district_name                 1758 non-null   object
#  2   school_number                 1758 non-null   int64
#  3   school_name                   1758 non-null   object
#  4   year                          1758 non-null   int64
#  5   street_address                1758 non-null   object
#  6   city                          1758 non-null   object
#  7   state                         1758 non-null   object
#  8   zipcode                       1758 non-null   int64
#  9   phone1                        1758 non-null   object
#  10  countyname_full               1758 non-null   object
#  11  countyname_short              1758 non-null   object
# ...

# %%
#combined_df3.to_excel(r'210608_combined_school_test_v2.xlsx', index = False)

# %% [markdown]
# ## Add Additional Fields Already in District Data

# %%
af_df = pd.read_excel("210610_combined_school_test.xlsx", sheet_name=0)

# %%
af_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1759 entries, 0 to 1758
# Data columns (total 72 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   district_number               1759 non-null   int64
#  1   district_name                 1758 non-null   object
#  2   school_number                 1759 non-null   int64
#  3   school_name                   1759 non-null   object
#  4   year                          1759 non-null   int64
#  5   street_address                1758 non-null   object
#  6   city                          1758 non-null   object
#  7   state                         1758 non-null   object
#  8   zipcode                       1758 non-null   float64
#  9   phone1                        1758 non-null   object
#  10  countyname_full               1758 non-null   object
#  11  countyname_short              1758 non-null   object
# ...

# %%
profile_df = pd.read_excel("profile_10_19.xlsx", sheet_name=0)

# %%
profile_df.head()
# Out:
#    school_year  district  school_id    district_name  \
# 0         2010        10          2  Anderson County
# 1         2010        10          3  Anderson County
# 2         2010        10          5  Anderson County
# 3         2010        10         10  Anderson County
# 4         2010        10         15  Anderson County
#
#                                school_name grades_served  safe_school  \
# 0              Anderson County High School          9-12  Safe School
# 1  Anderson County Career Technical Center         10-12  Safe School
# 2                 Andersonville Elementary          PK-5  Safe School
# 3                    Briceville Elementary          PK-5  Safe School
# 4                       Claxton Elementary          PK-5  Safe School
#
#   average_daily_membership total white  ... hispanic_pct asian_pct  \
# 0                     1053  1066  1049  ...          0.4       0.8
# 1                        -   NaN   NaN  ...          NaN       NaN
# ...

# %%
profile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18479 entries, 0 to 18478
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   school_year                     18479 non-null  int64
#  1   district                        18479 non-null  int64
#  2   school_id                       18479 non-null  int64
#  3   district_name                   18479 non-null  object
#  4   school_name                     18478 non-null  object
#  5   grades_served                   18465 non-null  object
#  6   safe_school                     18467 non-null  object
#  7   average_daily_membership        17817 non-null  object
#  8   total                           18237 non-null  object
#  9   white                           17933 non-null  object
#  10  african_american                17691 non-null  object
#  11  hispanic                        17447 non-null  object
# ...

# %%
profile_df = profile_df[(profile_df.school_year == 2019)]

# %%
profile_df = profile_df.rename({'district' : 'district_number', 'school_id' : 'school_number'},axis=1)

# %%
profile_df.head()
# Out:
#        school_year  district_number  school_number  \
# 16723         2019              985           8050
# 16724         2019              985           8025
# 16725         2019              985           8024
# 16726         2019              985           8005
# 16727         2019              985           8010
#
#                      district_name                         school_name  \
# 16723  Achievement School District                      Aspire Coleman
# 16724  Achievement School District            Aspire Hanley Elementary
# 16725  Achievement School District         Aspire Hanley Middle School
# 16726  Achievement School District  Brick Church: A LEAD Public School
# 16727  Achievement School District    Cornerstone Prep - Lester Campus
#
#       grades_served  safe_school average_daily_membership total white  ...  \
# 16723   Grades PK-7  SAFE SCHOOL                      607   612     8  ...
# 16724   Grades PK-5  SAFE SCHOOL                      530   544     0  ...
# ...

# %%
profile_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1756 entries, 16723 to 18478
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   school_year                     1756 non-null   int64
#  1   district_number                 1756 non-null   int64
#  2   school_number                   1756 non-null   int64
#  3   district_name                   1756 non-null   object
#  4   school_name                     1756 non-null   object
#  5   grades_served                   1755 non-null   object
#  6   safe_school                     1756 non-null   object
#  7   average_daily_membership        1751 non-null   object
#  8   total                           1756 non-null   object
#  9   white                           1756 non-null   object
#  10  african_american                1756 non-null   object
#  11  hispanic                        1756 non-null   object
# ...

# %%
combined_df4 = pd.merge(af_df, profile_df[['school_number','district_number', 'male', 'female', 'male_pct', 'female_pct', 'economically_disadvantaged', 'limited_english_proficient_pct', 'limited_english_proficient', 'students_with_disabilities', 'students_with_disabilities_pct']], on=['school_number', 'district_number'], how='left')

# %%
combined_df4.shape
# Out:
# (1759, 81)

# %%
combined_df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1759 entries, 0 to 1758
# Data columns (total 81 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   district_number                 1759 non-null   int64
#  1   district_name                   1758 non-null   object
#  2   school_number                   1759 non-null   int64
#  3   school_name                     1759 non-null   object
#  4   year                            1759 non-null   int64
#  5   street_address                  1758 non-null   object
#  6   city                            1758 non-null   object
#  7   state                           1758 non-null   object
#  8   zipcode                         1758 non-null   float64
#  9   phone1                          1758 non-null   object
#  10  countyname_full                 1758 non-null   object
#  11  countyname_short                1758 non-null   object
# ...

# %% [markdown]
# ## Chronic Absenteeism

# %%
ca_df = pd.read_excel("chronic_absenteeism.xlsx", sheet_name=0)

# %%
ca_df.head()
# Out:
#    district_number       district_name  school_number  school_name  year  \
# 0                0  State of Tennessee              0  All Schools  2019
# 1                0  State of Tennessee              0  All Schools  2019
# 2                0  State of Tennessee              0  All Schools  2019
# 3                0  State of Tennessee              0  All Schools  2019
# 4                0  State of Tennessee              0  All Schools  2019
#
#        subgroup  denominator percent_ca percent_ca_previous  baseline_year
# 0  all_students     970766.0       12.5                12.9         2018.0
# 1  all_students     970766.0       12.5                12.9         2018.0
# 2           bhn     333697.0       14.7                14.6         2018.0
# 3           bhn     333697.0       14.7                14.6         2018.0
# 4            ed     297855.0       19.5                20.7         2018.0

# %%
ca_df = ca_df[(ca_df.school_name != 'All Schools') & (ca_df.subgroup == 'all_students')]

# %%
ca_df.head()
# Out:
#     district_number            district_name  school_number  \
# 15               10  Anderson County Schools              2
# 20               10  Anderson County Schools              5
# 25               10  Anderson County Schools             10
# 30               10  Anderson County Schools             15
# 35               10  Anderson County Schools             20
#
#                     school_name  year      subgroup  denominator percent_ca  \
# 15  Anderson County High School  2019  all_students       1073.0       15.1
# 20     Andersonville Elementary  2019  all_students        304.0        8.6
# 25        Briceville Elementary  2019  all_students        117.0        9.4
# 30           Claxton Elementary  2019  all_students        445.0       14.4
# 35        Clinton Middle School  2019  all_students        663.0       20.8
#
#    percent_ca_previous  baseline_year
# 15                18.3         2018.0
# 20                10.6         2018.0
# ...

# %%
ca_df = ca_df.rename({'percent_ca' : 'chronic_absent_pct'},axis=1)

# %%
ca_df.head()
# Out:
#     district_number            district_name  school_number  \
# 15               10  Anderson County Schools              2
# 20               10  Anderson County Schools              5
# 25               10  Anderson County Schools             10
# 30               10  Anderson County Schools             15
# 35               10  Anderson County Schools             20
#
#                     school_name  year      subgroup  denominator  \
# 15  Anderson County High School  2019  all_students       1073.0
# 20     Andersonville Elementary  2019  all_students        304.0
# 25        Briceville Elementary  2019  all_students        117.0
# 30           Claxton Elementary  2019  all_students        445.0
# 35        Clinton Middle School  2019  all_students        663.0
#
#    chronic_absent_pct percent_ca_previous  baseline_year
# 15               15.1                18.3         2018.0
# 20                8.6                10.6         2018.0
# ...

# %%
combined_df5 = pd.merge(combined_df4, ca_df[['school_number','district_number', 'chronic_absent_pct']], on=['school_number', 'district_number'], how='left')

# %%
combined_df5.shape
# Out:
# (1759, 82)

# %%
#combined_df5.to_excel(r'210611_combined_school_test.xlsx', index = False)

# %% [markdown]
# ## Gini Index Correlation?

# %%
combined_df5.head()
# Out:
#    district_number            district_name  school_number  \
# 0                0                      NaN              0
# 1               10  Anderson County Schools              2
# 2               10  Anderson County Schools              5
# 3               10  Anderson County Schools             10
# 4               10  Anderson County Schools             15
#
#                    school_name  year      street_address           city state  \
# 0           State of Tennessee  2019                 NaN            NaN   NaN
# 1  Anderson County High School  2019   130 Maverick  Cir        Clinton    TN
# 2     Andersonville Elementary  2019  1951  Mountain  Rd  Andersonville    TN
# 3        Briceville Elementary  2019   103 Slatestone Rd     Briceville    TN
# 4           Claxton Elementary  2019  2218  Clinton  Hwy         Powell    TN
#
#    zipcode          phone1  ... male female male_pct female_pct  \
# 0      NaN             NaN  ...  NaN    NaN      NaN        NaN
# ...

# %%
davidson_only = combined_df5[(combined_df5.countyname_short == 'Shelby')]

# %%
davidson_only[['Gini Index', 'total_diff_abs']].corr()
# Out:
#                 Gini Index  total_diff_abs
# Gini Index        1.000000        0.185173
# total_diff_abs    0.185173        1.000000

# %%
davidson_only[['Gini Index', 'total_diff']].corr()
# Out:
#             Gini Index  total_diff
# Gini Index    1.000000    0.142459
# total_diff    0.142459    1.000000

# %%
combined_df5[['Gini Index', 'total_diff']].corr()
# Out:
#             Gini Index  total_diff
# Gini Index    1.000000   -0.019891
# total_diff   -0.019891    1.000000

# %% [markdown]
# ## Add Success Rate

# %%
sr_df = pd.read_excel("success_rate.xlsx", sheet_name=0)

# %%
sr_df = sr_df[(sr_df.school_name != 'All Schools') & (sr_df.subgroup == 'all_students')]

# %%
sr_df.head()
# Out:
#     district_number            district_name  school_number  \
# 15               10  Anderson County Schools              2
# 21               10  Anderson County Schools              5
# 27               10  Anderson County Schools             10
# 33               10  Anderson County Schools             15
# 39               10  Anderson County Schools             20
#
#                     school_name  year      subgroup  denominator success_rate  \
# 15  Anderson County High School  2019  all_students       1314.0         36.8
# 21     Andersonville Elementary  2019  all_students        316.0         48.7
# 27        Briceville Elementary  2019  all_students        106.0         27.4
# 33           Claxton Elementary  2019  all_students        421.0         29.2
# 39        Clinton Middle School  2019  all_students       1298.0           32
#
#    success_rate_previous  baseline_year
# 15                  31.5         2018.0
# 21                  40.1         2018.0
# ...

# %%
sr_df = sr_df.rename({'success_rate' : 'success_rate2019','success_rate_previous' : 'success_rate2018'},axis=1)

# %%
sr_df.head()
# Out:
#     district_number            district_name  school_number  \
# 15               10  Anderson County Schools              2
# 21               10  Anderson County Schools              5
# 27               10  Anderson County Schools             10
# 33               10  Anderson County Schools             15
# 39               10  Anderson County Schools             20
#
#                     school_name  year      subgroup  denominator  \
# 15  Anderson County High School  2019  all_students       1314.0
# 21     Andersonville Elementary  2019  all_students        316.0
# 27        Briceville Elementary  2019  all_students        106.0
# 33           Claxton Elementary  2019  all_students        421.0
# 39        Clinton Middle School  2019  all_students       1298.0
#
#    success_rate2019 success_rate2018  baseline_year
# 15             36.8             31.5         2018.0
# 21             48.7             40.1         2018.0
# 27             27.4             23.6         2018.0
# ...

# %%
combined_df5 = pd.merge(combined_df5, sr_df[['school_number','district_number', 'success_rate2019', 'success_rate2018']], on=['school_number', 'district_number'], how='left')

# %%
combined_df5.shape
# Out:
# (1759, 84)

# %% [markdown]
# ## Add in County Rankings

# %%
cre_df = pd.read_excel("county_rank_elementary.xlsx", sheet_name=0)

# %%
cre_df.head()
# Out:
#   countyname_short                        school_name  county_rank_elementary  \
# 0          Overton             A H Roberts Elementary                       5
# 1             Knox               A L Lotts Elementary                       9
# 2           Shelby              A. B. Hill Elementary                      50
# 3         Davidson            A. Z. Kelley Elementary                      28
# 4         Sullivan  Abraham Lincoln Elementary School                      15
#
#    c.School Type Calc on Rank
# 0                         713
# 1                         126
# 2                         635
# 3                         659
# 4                         575

# %%
combined_df6 = pd.merge(combined_df5, cre_df[['countyname_short','school_name', 'county_rank_elementary']], on=['countyname_short', 'school_name'], how='left')

# %%
combined_df6.shape
# Out:
# (1759, 85)

# %%
crm_df = pd.read_excel("county_rank_middle.xlsx", sheet_name=0)

# %%
crm_df.head()
# Out:
#   countyname_short             school_name  county_rank_middle  \
# 0           Shelby  A. Maceo Walker Middle                  43
# 1           Blount     Alcoa Middle School                   5
# 2           Putnam    Algood Middle School                   1
# 3         Fentress      Allardt Elementary                   1
# 4          Overton       Allons Elementary                   5
#
#    c.School Type Calc on Rank
# 0                         496
# 1                         172
# 2                         198
# 3                         163
# 4                         379

# %%
combined_df6 = pd.merge(combined_df6, crm_df[['countyname_short','school_name', 'county_rank_middle']], on=['countyname_short', 'school_name'], how='left')

# %%
combined_df6.shape
# Out:
# (1759, 86)

# %%
crh_df = pd.read_excel("county_rank_high.xlsx", sheet_name=0)

# %%
crh_df.head()
# Out:
#   countyname_short                  school_name  county_rank_high  \
# 0          McNairy       Adamsville High School                 1
# 1           Blount            Alcoa High School                 2
# 2         Anderson  Anderson County High School                 2
# 3         Davidson          Antioch High School                23
# 4           Shelby               Arlington High                 7
#
#    c.School Type Calc on Rank
# 0                         149
# 1                          49
# 2                         101
# 3                         332
# 4                          67

# %%
combined_df6 = pd.merge(combined_df6, crh_df[['countyname_short','school_name', 'county_rank_high']], on=['countyname_short', 'school_name'], how='left')

# %%
combined_df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1759 entries, 0 to 1758
# Data columns (total 87 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   district_number                 1759 non-null   int64
#  1   district_name                   1758 non-null   object
#  2   school_number                   1759 non-null   int64
#  3   school_name                     1759 non-null   object
#  4   year                            1759 non-null   int64
#  5   street_address                  1758 non-null   object
#  6   city                            1758 non-null   object
#  7   state                           1758 non-null   object
#  8   zipcode                         1758 non-null   float64
#  9   phone1                          1758 non-null   object
#  10  countyname_full                 1758 non-null   object
#  11  countyname_short                1758 non-null   object
# ...

# %% [markdown]
# ## Add Dropout Rate

# %%
dor_df = pd.read_excel("dropout.xlsx", sheet_name=0)

# %%
dor_df.head()
# Out:
#    district_number       district_name  school_number  school_name  year  \
# 0                0  State of Tennessee              0  All Schools  2018
# 1                0  State of Tennessee              0  All Schools  2018
# 2                0  State of Tennessee              0  All Schools  2018
# 3                0  State of Tennessee              0  All Schools  2018
# 4                0  State of Tennessee              0  All Schools  2018
#
#        subgroup  denominator percent_dropout  baseline_year  \
# 0  all_students      72784.0             8.3         2017.0
# 1  all_students      72784.0             8.3         2017.0
# 2           bhn      24112.0            13.7         2017.0
# 3           bhn      24112.0            13.7         2017.0
# 4            ed      26714.0            13.9         2017.0
#
#   percent_dropout_previous
# 0                        7
# 1                        7
# 2                     11.3
# 3                     11.3
# ...

# %%
dor_df = dor_df[(dor_df.school_name != 'All Schools') & (dor_df.subgroup == 'all_students')]

# %%
dor_df.tail()
# Out:
#        district_number            district_name  school_number  \
# 10725              500  Lawrence County Schools             90
# 10790               51       Alcoa City Schools              5
# 10855              510     Lewis County Schools              3
# 10933               52   Maryville City Schools             20
# 11167              530    Loudon County Schools             18
#
#                         school_name  year      subgroup  denominator  \
# 10725         Summertown Elementary  2018  all_students          NaN
# 10790              Alcoa Elementary  2018  all_students          NaN
# 10855    Lewis County Middle School  2018  all_students          NaN
# 10933  Maryville Junior High School  2018  all_students          0.0
# 11167      Ft Loudoun Middle School  2018  all_students          NaN
#
#       percent_dropout  baseline_year percent_dropout_previous
# 10725               *         2017.0                        *
# ...

# %%
combined_df7 = pd.merge(combined_df6, dor_df[['school_number','district_number', 'percent_dropout']], on=['school_number', 'district_number'], how='left')

# %%
combined_df7.shape
# Out:
# (1759, 88)

# %%
#combined_df7.to_excel(r'210620_combined_school_data.xlsx', index = False)
