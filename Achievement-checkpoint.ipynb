# %% [markdown]
# # Achievement

# %%
import pandas as pd
import numpy as np

# %%
ach_df = pd.read_excel("achievement.xlsx", sheet_name=0)

# %%
ach_df.head()
# Out:
#    district_number       district_name  school_number  school_name  year  \
# 0                0  State of Tennessee              0  All Schools  2019
# 1                0  State of Tennessee              0  All Schools  2019
# 2                0  State of Tennessee              0  All Schools  2019
# 3                0  State of Tennessee              0  All Schools  2019
# 4                0  State of Tennessee              0  All Schools  2019
#
#        subgroup overall_subject percent_below percent_approaching  \
# 0  all_students             ELA          19.6                45.5
# 1  all_students             ELA          19.6                45.5
# 2           bhn             ELA            30                48.9
# 3           bhn             ELA            30                48.9
# 4            ed             ELA          30.9                49.5
#
#   percent_on_track percent_mastered percent_on_mastered  baseline_year  \
# ...

# %%
ach_df = ach_df[(ach_df.school_name != 'All Schools') & (ach_df.subgroup == 'all_students') & (ach_df.overall_subject != 'Social Studies') ]

# %%
ach_df.drop(columns=['percent_mastered'], inplace=True)

# %%
ach_df.head()
# Out:
#      district_number            district_name  school_number  \
# 144               10  Anderson County Schools              2
# 160               10  Anderson County Schools              2
# 192               10  Anderson County Schools              5
# 208               10  Anderson County Schools              5
# 240               10  Anderson County Schools             10
#
#                      school_name  year      subgroup overall_subject  \
# 144  Anderson County High School  2019  all_students             ELA
# 160  Anderson County High School  2019  all_students            Math
# 192     Andersonville Elementary  2019  all_students             ELA
# 208     Andersonville Elementary  2019  all_students            Math
# 240        Briceville Elementary  2019  all_students             ELA
#
#     percent_below percent_approaching percent_on_track percent_on_mastered  \
# 144            **                  **               **                40.7
# ...
